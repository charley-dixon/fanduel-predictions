# %% [markdown]
# # General Assembly DSI - Denver 2018
# ## Capstone Project - DFS Model
# This is my capstone project at General Assembly's fifth [Data Science Immersive](https://generalassemb.ly/education/data-science-immersive) cohort in 2018. I am developing a model to assist in optimizing NFL lineups on the daily fantasy sports platforms [Draft Kings](https://www.draftkings.com/) and [Fan Duel](https://www.fanduel.com/).
#
# ### Problem Statement
#
# Can we build a model to predict a football player’s fantasy football performance to estimate their value and implement the model in conjunction with a daily fantasy strategy to be profitable?

# %%
import pandas as pd

# %%
qb_stats = pd.read_csv('../data/qb_stats.csv')
quarterbacks = pd.read_csv('../data/quarterbacks.csv')

# %%
qb_stats.head()
# Out:
#       Age  Attempts  Completions  Interceptions               Name Oppt  \
# 0  28.291        25           17              0  Fitzpatrick, Ryan   KC
# 1  27.280        35           27              0     Rodgers, Aaron   NO
# 2  34.040        48           32              1         Brady, Tom  MIA
# 3  23.216        33           24              1  Stafford, Matthew   TB
# 4  26.238        29           17              0        Flacco, Joe  PIT
#
#    Rating  TDs Team  Week    Y/A  Yards  Year  Month
# 0   133.0    4  BUF     1   8.32    208  2011      9
# 1   132.1    3   GB     1   8.91    312  2011      9
# 2   121.6    4   NE     1  10.77    517  2011      9
# 3   118.9    3  DET     1   9.24    305  2011      9
# 4   117.6    3  BAL     1   7.72    224  2011      9

# %%
quarterbacks.head()
# Out:
#              Name  Week  Year Team Oppt  h/a  FD points  FD salary  \
# 0  Batch, Charlie     2  2011  PIT  SEA    1       0.00     5000.0
# 1   Bradford, Sam     2  2011  LAR  NYG    0      16.74     7300.0
# 2      Brady, Tom     2  2011   NE  LAC    1      29.22     9100.0
# 3     Brees, Drew     2  2011   NO  CHI    1      23.00     9300.0
# 4   Brunell, Mark     2  2011  NYJ  JAX    1       0.00     5000.0
#
#    Opp_Avg_Att_Allowed  Opp_Avg_Comp_Allowed      ...        Temperature  \
# 0                 29.0                  17.0      ...               63.0
# 1                 32.0                  14.0      ...               68.0
# 2                 49.0                  30.0      ...               63.0
# 3                 35.0                  27.0      ...               72.0
# 4                 36.0                  23.0      ...               71.0
#
#    Wind  Weather_DOME  Weather_Fog  Weather_Rain  Weather_Rain | Fog  \
# 0   1.0             0            0             0                   0
# 1   6.0             0            0             0                   0
# 2  12.0             0            0             0                   0
# 3   0.0             1            0             0                   0
# 4   1.0             0            0             0                   0
#
#    Weather_Snow  Weather_Snow | Fog  Weather_Snow | Freezing Rain  \
# 0             0                   0                             0
# 1             0                   0                             0
# 2             0                   0                             0
# 3             0                   0                             0
# 4             0                   0                             0
#
#    Weather_Sunny
# 0              1
# 1              1
# 2              1
# 3              0
# 4              1
#
# [5 rows x 27 columns]

# %%
quarterbacks.shape
# Out:
# (4136, 27)

# %%
pd.merge(quarterbacks, qb_stats, on = ['Name', 'Team', 'Week', 'Year', 'Oppt']).shape
# Out:
# (2664, 36)

# %% [markdown]
# > Because we scraped player stats by those players who were active, many of the players were removed from the dataset upon merging.

# %%
quarterbacks = pd.merge(quarterbacks, qb_stats, on = ['Name', 'Team', 'Week', 'Year', 'Oppt'])

# %%
quarterbacks.head()
# Out:
#             Name  Week  Year Team Oppt  h/a  FD points  FD salary  \
# 0  Bradford, Sam     2  2011  LAR  NYG    0      16.74     7300.0
# 1     Brady, Tom     2  2011   NE  LAC    1      29.22     9100.0
# 2    Brees, Drew     2  2011   NO  CHI    1      23.00     9300.0
# 3   Cassel, Matt     2  2011   KC  DET    0       0.32     7700.0
# 4   Dalton, Andy     2  2011  CIN  DEN    0      21.58     5100.0
#
#    Opp_Avg_Att_Allowed  Opp_Avg_Comp_Allowed  ...    Weather_Sunny     Age  \
# 0                 32.0                  14.0  ...                1  23.315
# 1                 49.0                  30.0  ...                1  34.046
# 2                 35.0                  27.0  ...                0  32.246
# 3                 25.0                  17.0  ...                0  29.124
# 4                 40.0                  19.0  ...                1  23.324
#
#    Attempts  Completions  Interceptions  Rating  TDs    Y/A  Yards  Month
# 0        46           22              0    79.2    1   7.20    331      9
# 1        40           31              0   135.7    3  10.58    423      9
# 2        37           26              0   118.1    3   7.30    270      9
# 3        22           15              3    44.5    0   6.05    133      9
# 4        41           27              0   107.0    2   8.10    332      9
#
# [5 rows x 36 columns]

# %%
quarterbacks.groupby(['Name', 'Year', 'Week'])[['Attempts', 'Completions', 'Interceptions', 
                                                               'Rating', 'TDs', 'Y/A', 'Yards']].sum().head(10)
# Out:
#                          Attempts  Completions  Interceptions  Rating  TDs  \
# Name          Year Week
# Barkley, Matt 2013 7           20           11              3    35.2    0
#                    8           26           17              1    65.9    0
#                    9            3            2              0    75.7    0
#               2014 10           1            0              0    39.6    0
#               2016 7           15            6              2    18.3    0
#                    12          54           28              2    72.8    3
#                    13          18           11              0    97.5    0
#                    14          32           20              0    92.2    1
#                    15          43           30              3    81.7    2
#                    16          40           24              5    62.8    2
#
#                            Y/A  Yards
# Name          Year Week
# Barkley, Matt 2013 7      6.45    129
#                    8      6.08    158
#                    9      4.33     13
#               2014 10     0.00      0
#               2016 7      5.40     81
#                    12     5.85    316
#                    13    10.67    192
#                    14     6.63    212
#                    15     8.42    362
#                    16     8.08    323

# %%
features = ['Attempts', 'Completions', 'Interceptions', 'Rating', 'TDs', 'Y/A', 'Yards']

# %%
rolling_qb_stats = quarterbacks.groupby(['Name', 'Year'])[features].rolling(window = 3, min_periods = 0).mean()

# %%
shifted_qb_stats = rolling_qb_stats.groupby(level = [0,1]).shift()

# %%
shifted_qb_stats.head()
# Out:
#                          Attempts  Completions  Interceptions  Rating  TDs  \
# Name          Year
# Barkley, Matt 2013 882        NaN          NaN            NaN     NaN  NaN
#                    1048      20.0         11.0            3.0   35.20  0.0
#                    1203      23.0         14.0            2.0   50.55  0.0
#               2014 1385       NaN          NaN            NaN     NaN  NaN
#               2016 955        NaN          NaN            NaN     NaN  NaN
#
#                            Y/A  Yards
# Name          Year
# Barkley, Matt 2013 882     NaN    NaN
#                    1048  6.450  129.0
#                    1203  6.265  143.5
#               2014 1385    NaN    NaN
#               2016 955     NaN    NaN

# %%
for index, row in quarterbacks.iterrows():
    rolling_index = (row['Name'], row['Year'], index)
    quarterbacks.loc[index, features] = shifted_qb_stats.loc[rolling_index, features]

# %%
quarterbacks.dropna(inplace = True)

# %%
quarterbacks['Month'] = quarterbacks['Month'].map({12: 'December', 11: 'November', 10: 'October', 9: 'September', 1: 'January'})

# %%
# quarterbacks.to_csv('../data/quarterbacks_final.csv', index = False)

# %% [markdown]
# ### Runningbacks

# %%
runningbacks = pd.read_csv('../data/runningbacks.csv')
rb_stats = pd.read_csv('../data/rb_stats.csv')

# %%
runningbacks.head()
# Out:
#    Week  Year   GID              Name Pos Team h/a Oppt  FD points  FD salary  \
# 0     2  2011  2603  McFadden, Darren  RB  OAK   a  BUF       27.8     9100.0
# 1     2  2011  2536     Bush, Michael  RB  OAK   a  BUF        8.3     5900.0
# 2     2  2011  2665     Reece, Marcel  RB  OAK   a  BUF        3.9     4500.0
# 3     2  2011  2820     Jones, Taiwan  RB  OAK   a  BUF        0.4     4500.0
# 4     2  2011  2332  Cartwright, Rock  RB  OAK   a  BUF        0.0     4500.0
#
#    Opp_Avg_Carries  Opp_Rank  Opp_Avg_TDs_Allowed  Opp_Avg_Yds_Allowed  \
# 0             12.0         4                  0.0                 25.0
# 1             12.0         4                  0.0                 25.0
# 2             12.0         4                  0.0                 25.0
# 3             12.0         4                  0.0                 25.0
# 4             12.0         4                  0.0                 25.0
#
#   Favored  Spread   O/U Weather  Temperature  Wind
# 0     BUF    -4.0  41.0   Sunny         66.0   5.0
# 1     BUF    -4.0  41.0   Sunny         66.0   5.0
# 2     BUF    -4.0  41.0   Sunny         66.0   5.0
# 3     BUF    -4.0  41.0   Sunny         66.0   5.0
# 4     BUF    -4.0  41.0   Sunny         66.0   5.0

# %%
runningbacks.shape
# Out:
# (12339, 20)

# %%
rb_stats.head()
# Out:
#       Age  Carries        Date     Month                Name Oppt  Rec_TDs  \
# 0  26.238     16.0  2011-11-14  November    Peterson, Adrian   GB      0.0
# 1  24.343      5.0  2011-11-13  November  Blount, LeGarrette  HOU      0.0
# 2  28.183     22.0  2011-11-13  November         Gore, Frank  NYG      0.0
# 3  21.327     13.0  2011-11-13  November        Ingram, Mark  ATL      0.0
# 4  21.047      2.0  2011-11-13  November         Lewis, Dion  ARI      0.0
#
#    Rec_Yds  Receptions  Rush_TDs  Rush_Yds  Targets Team  Week  Year
# 0      6.0         2.0       0.0      98.0      3.0  MIN    10  2011
# 1      0.0         0.0       0.0      15.0      0.0   TB    10  2011
# 2     19.0         3.0       0.0      59.0      4.0   SF    10  2011
# 3      0.0         0.0       0.0      40.0      0.0   NO    10  2011
# 4     -3.0         1.0       0.0      10.0      1.0  PHI    10  2011

# %%
rb_stats.shape
# Out:
# (3826, 15)

# %%
runningbacks = pd.merge(runningbacks, rb_stats, on = ['Name', 'Week', 'Year', 'Team', 'Oppt'])

# %%
runningbacks.shape
# Out:
# (3703, 30)

# %%
runningbacks['Year'].value_counts()
# Out:
# 2017    1061
# 2016     813
# 2015     646
# 2014     501
# 2013     304
# 2012     236
# 2011     142
# Name: Year, dtype: int64

# %%
runningbacks.columns
# Out:
# Index(['Week', 'Year', 'Name', 'Team', 'h/a', 'Oppt', 'FD points', 'FD salary',
#        'Opp_Avg_Carries', 'Opp_Rank', 'Opp_Avg_TDs_Allowed',
#        'Opp_Avg_Yds_Allowed', 'Favored', 'Spread', 'O/U', 'Weather',
#        'Temperature', 'Wind', 'Age', 'Carries', 'Month', 'Rec_TDs', 'Rec_Yds',
#        'Receptions', 'Rush_TDs', 'Rush_Yds', 'Targets'],
#       dtype='object')

# %%
runningbacks.drop(['Pos'], axis = 1, inplace = True)

# %%
rb_cols = ['Name', 'Age', 'Week', 'Year', 'Team', 'Oppt', 'h/a', 'Favored', 'Spread', 'O/U', 'Weather', 'Temperature',
           'Wind', 'Month', 'Carries', 'Rush_Yds', 'Rush_TDs', 'Receptions', 'Targets', 'Rec_Yds', 'Rec_TDs',
           'Opp_Avg_Carries', 'Opp_Rank', 'Opp_Avg_TDs_Allowed', 'Opp_Avg_Yds_Allowed', 'FD salary', 'FD points']

runningbacks = runningbacks[rb_cols]

# %%
# runningbacks.to_csv('../data/runningbacks_final.csv')

# %% [markdown]
# ### Wide Receivers

# %%
receivers = pd.read_csv('../data/receivers.csv')
wr_stats = pd.read_csv('../data/wr_stats.csv')

# %%
receivers.shape
# Out:
# (15662, 21)

# %%
wr_stats.shape
# Out:
# (6932, 11)

# %%
receivers.head()
# Out:
#    Week  Year   GID             Name Pos Team h/a Oppt  FD points  FD salary  \
# 0     2  2011  3610    Austin, Miles  WR  DAL   a   SF       36.6     7100.0
# 1     2  2011  3934    Holley, Jesse  WR  DAL   a   SF       11.1     4500.0
# 2     2  2011  3876  Ogletree, Kevin  WR  DAL   a   SF        5.6     4500.0
# 3     2  2011  5130   Harris, Dwayne  WR  DAL   a   SF        0.0     4500.0
# 4     2  2011  5076   Williams, Kyle  WR   SF   h  DAL        7.7     4500.0
#
#    ...   Opp_Avg_Rec_Allowed  Opp_Avg_Targets_Allowed  Opp_Avg_TDs_Allowed  \
# 0  ...                  13.0                     25.0                  1.0
# 1  ...                  13.0                     25.0                  1.0
# 2  ...                  13.0                     25.0                  1.0
# 3  ...                  13.0                     25.0                  1.0
# 4  ...                  11.0                     22.0                  2.0
#
#    Opp_Avg_Yds_Allowed  Favored Spread   O/U  Weather Temperature  Wind
# 0                161.0      DAL   -3.0  41.5    Sunny        72.0   3.0
# 1                161.0      DAL   -3.0  41.5    Sunny        72.0   3.0
# 2                161.0      DAL   -3.0  41.5    Sunny        72.0   3.0
# 3                161.0      DAL   -3.0  41.5    Sunny        72.0   3.0
# 4                137.0      DAL   -3.0  41.5    Sunny        72.0   3.0
#
# [5 rows x 21 columns]

# %%
wr_stats.head()
# Out:
#       Age  Month            Name Oppt   Rec_TDs     Rec_Yds  Receptions  \
# 0  22.362      9   Baldwin, Doug  PIT  0.666667   41.000000    3.333333
# 1  22.364      9    Britt, Kenny  BAL  2.000000  136.000000    5.000000
# 2  23.070      9  Brown, Antonio  SEA  0.333333   81.333333    4.333333
# 3  21.027      9   Cobb, Randall  CAR  0.000000   40.000000    2.666667
# 4  24.187      9    Decker, Eric  CIN  0.000000   18.333333    1.333333
#
#      Targets Team  Week  Year
# 0   5.666667  SEA     2  2011
# 1  10.000000  TEN     2  2011
# 2   8.000000  PIT     2  2011
# 3   3.000000   GB     2  2011
# 4   4.333333  DEN     2  2011

# %%
receivers = pd.merge(receivers, wr_stats, on = ['Name', 'Year', 'Week', 'Team', 'Oppt'])

# %%
receivers.drop(['GID', 'Pos'], axis = 1, inplace = True)

# %%
# receivers.to_csv('../data/receivers_final.csv', index = False)

# %% [markdown]
# ### Tight Ends

# %%
tight_ends = pd.read_csv('../data/tightends.csv')
te_stats = pd.read_csv('../data/te_stats.csv')

# %%
tight_ends.shape
# Out:
# (8840, 21)

# %%
te_stats.shape
# Out:
# (3187, 11)

# %%
tight_ends.head()
# Out:
#    Week  Year   GID             Name Pos Team h/a Oppt  FD points  FD salary  \
# 0     2  2011  4051   Gonzalez, Tony  TE  ATL   h  PHI       23.8     5700.0
# 1     2  2011  4138     Zelenka, Joe  TE  ATL   h  PHI        0.0     4500.0
# 2     2  2011  4074    Kelly, Reggie  TE  ATL   h  PHI        0.0     4500.0
# 3     2  2011  4512  Palmer, Michael  TE  ATL   h  PHI        0.0     4500.0
# 4     2  2011  4363     Celek, Brent  TE  PHI   a  ATL        6.3     4900.0
#
#    ...   Opp_Avg_Rec_Allowed  Opp_Avg_Targets_Allowed  Opp_Avg_TDs_Allowed  \
# 0  ...                   4.0                      7.0                  1.0
# 1  ...                   4.0                      7.0                  1.0
# 2  ...                   4.0                      7.0                  1.0
# 3  ...                   4.0                      7.0                  1.0
# 4  ...                   3.0                      8.0                  0.0
#
#    Opp_Avg_Yds_Allowed  Favored Spread   O/U  Weather Temperature  Wind
# 0                 30.0      PHI   -2.5  49.5     DOME        72.0   0.0
# 1                 30.0      PHI   -2.5  49.5     DOME        72.0   0.0
# 2                 30.0      PHI   -2.5  49.5     DOME        72.0   0.0
# 3                 30.0      PHI   -2.5  49.5     DOME        72.0   0.0
# 4                 39.0      PHI   -2.5  49.5     DOME        72.0   0.0
#
# [5 rows x 21 columns]

# %%
te_stats.head()
# Out:
#       Age      Month                   Name Oppt   Rec_TDs    Rec_Yds  \
# 0  23.077  September  Hoomanawanui, Michael  NYG  0.000000  21.000000
# 1  23.232  September       Kendricks, Lance  NYG  0.000000  19.333333
# 2  24.164  September            Cook, Jared  BAL  0.333333  90.666667
# 3  27.230  September          Davis, Vernon  DAL  0.333333  52.666667
# 4  24.055  September            Dickson, Ed  TEN  0.666667  23.000000
#
#    Receptions   Targets Team  Week  Year
# 0    2.000000  3.000000  LAR     2  2011
# 1    2.000000  3.000000  LAR     2  2011
# 2    5.666667  6.666667  TEN     2  2011
# 3    3.666667  7.000000   SF     2  2011
# 4    2.333333  3.666667  BAL     2  2011

# %%
# tight_ends = 
tight_ends = pd.merge(tight_ends, te_stats, on = ['Name', 'Year', 'Week', 'Team', 'Oppt'])

# %%
tight_ends.drop(['GID', 'Pos'], axis = 1, inplace = True)

# %%
# tight_ends.to_csv('../data/tightends_final.csv', index = False)
